# %% [markdown]
#  # Simplificando pandas, lectura y escritura de archivos II

# %% [markdown]
#  Importamos las librerias a utilizar

# %%
import os
from pathlib import Path
import glob
import numpy as np
import pandas as pd

# %% [markdown]
#  # Módulo pathlib

# %%
# directorio actual
dir_prin = Path.cwd()
dir_prin
# Out:
# WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv')

# %%
# directorio con los datos
dir_entra = dir_prin/'entradas'
dir_entra
# Out:
# WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas')

# %%
# directorio con los datos intermedios
dir_inter = dir_prin /'intermedios'
dir_inter
# Out:
# WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/intermedios')

# %%
# directorio con los datos finales
dir_salid = dir_prin / 'salidas'
dir_salid
# Out:
# WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/salidas')

# %% [markdown]
#  ## Extraer informacion de varios archivos

# %%
# Lista de los nombres de los archivos de interes
lista_csv = [f for f in dir_entra.glob("*.csv")]
lista_csv
# Out:
# [WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/01_enero.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/02_febrero.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/03_marzo.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/04_abril.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/05_mayo.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/06_junio.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/07_julio.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/08_agosto.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/09_septiembre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/10_octubre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/11_noviembre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/12_diciembre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/ejemplo.csv')]

# %%
# Lista final de los nombres de los archivos de interes
lista_csv = [f for f in dir_entra.glob("*.csv") if "ejemplo.csv" not in str(f)]
lista_csv
# Out:
# [WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/01_enero.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/02_febrero.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/03_marzo.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/04_abril.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/05_mayo.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/06_junio.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/07_julio.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/08_agosto.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/09_septiembre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/10_octubre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/11_noviembre.csv'),
#  WindowsPath('c:/Users/Waltter/OneDrive/Canal/Code/07-pandas_csv/entradas/12_diciembre.csv')]

# %% [markdown]
#  ### Dataframe vacío

# %%
clima = pd.DataFrame({'time':[],'precipIntensity':[],
                    'temperature':[],'apparentTemperature':[],
                    'dewPoint':[],'humidity':[],'pressure':[],
                    'windSpeed':[],'cloudCover':[]})
columnas = ['time','precipIntensity','temperature','apparentTemperature',
            'dewPoint','humidity','pressure','windSpeed','cloudCover']

# %% [markdown]
#  Comenzamos a cargar los datos

# %%
for archivo in lista_csv:
    clima_temp = pd.read_csv(archivo)
    # Seleccionamos las columnas de interes
    clima_temp = clima_temp[columnas]
    # Unimos Dataframnes
    clima = pd.concat([clima, clima_temp], join='inner', axis=0)
    clima = clima[columnas]
clima = clima.set_index('time')

# %% [markdown]
#  ### Verifiquemos el archivo creado

# %%
clima.head()
# Out:
#                      precipIntensity  temperature  apparentTemperature  \
# time
# 2018-01-01 00:00:00              0.0        22.44                22.73
# 2018-01-01 01:00:00              0.0        21.88                22.15
# 2018-01-01 02:00:00              0.0        21.33                21.63
# 2018-01-01 03:00:00              0.0        20.77                21.07
# 2018-01-01 04:00:00              0.0        19.11                19.33
#
#                      dewPoint  humidity  pressure  windSpeed  cloudCover
# time
# 2018-01-01 00:00:00     18.10      0.77       NaN        0.0        0.19
# 2018-01-01 01:00:00     17.75      0.77       NaN        0.0         NaN
# 2018-01-01 02:00:00     17.94      0.81       NaN        0.0         NaN
# 2018-01-01 03:00:00     17.75      0.83       NaN        0.0         NaN
# 2018-01-01 04:00:00     16.79      0.86       NaN        0.0         NaN

# %%
clima.tail()
# Out:
#                      precipIntensity  temperature  apparentTemperature  \
# time
# 2018-12-31 19:00:00              NaN        21.59                22.18
# 2018-12-31 20:00:00              NaN        22.12                22.44
# 2018-12-31 21:00:00              NaN        21.13                21.53
# 2018-12-31 22:00:00              NaN        21.13                21.49
# 2018-12-31 23:00:00              NaN        20.13                20.57
#
#                      dewPoint  humidity  pressure  windSpeed  cloudCover
# time
# 2018-12-31 19:00:00     20.00      0.91       NaN        NaN         NaN
# 2018-12-31 20:00:00     18.30      0.79       NaN       3.60         NaN
# 2018-12-31 21:00:00     18.61      0.86       NaN       1.66         NaN
# 2018-12-31 22:00:00     18.30      0.84       NaN       4.96         0.0
# 2018-12-31 23:00:00     18.61      0.91       NaN       3.60         0.0

# %%
clima.shape
# Out:
# (8642, 8)

# %%
clima.dtypes
# Out:
# precipIntensity        float64
# temperature            float64
# apparentTemperature    float64
# dewPoint               float64
# humidity               float64
# pressure               float64
# windSpeed              float64
# cloudCover             float64
# dtype: object

# %% [markdown]
#  ## Guardemos la información

# %%
clima.to_csv(dir_inter / 'clima.csv')

# %% [markdown]
#  ## Cargar varios archivos, modificarlos y luego
#  ## guardarlos individualmente

# %%
for archivo in lista_csv:
    clima_temp = pd.read_csv(archivo)
    # Seleccionamos las columnas de interes
    clima_temp = clima_temp[columnas]
    clima_temp = clima_temp.set_index('time')
    archivo2 = dir_inter / ''.join([archivo.name[:6], '.csv'])
    clima_temp.to_csv(archivo2)
