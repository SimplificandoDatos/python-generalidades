# %% [markdown]
# <a href="https://colab.research.google.com/github/SimplificandoDatos/python-generalidades/blob/master/colab/Intro_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introducción al uso de Google Colab

# %% [markdown]
# ## Edición de texto

# %% [markdown]
# ## Casillas con videos

# %%
#@title Visualización de videos de youtube { display-mode: "form" }
#@markdown Por si quieres desperdiciar un poco de tu tiempo
from IPython.display import YouTubeVideo
YouTubeVideo('f-btfcLCZVY', width=600, height=400)

# %% [markdown]
# ## Carga de Datos

# %% [markdown]
# ### Carga de archivos locales

# %% [markdown]
# ## Enlazar con Google Drive

# %% [markdown]
# Este es el código para que puedas autorizar la conexión entre google collab y google drive.
#
# Luego de ejecutarlo, te aparecerá un enlace al cual debes dar click y te dará un un código que debes copiar y pegar en una caja que te aparecerá, con esto das la autorización.
#
# Luego solo queda que hagas actualizar en el tab de archivos y veras tu unidad montada y lista para utilizarse.

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %%
# !ls /content/drive/My\ Drive/sample_data
# Out:
# 01_enero.csv  12_diciembre.csv	prueba1.gdoc

# %% [markdown]
# Descargar un recurso al cuaderno
#
# !wget [url] -p drive/[Folder Name]

# %%
# !wget https://github.com/jbagnato/machine-learning/raw/master/sportimages.zip

# %%
# !unzip -uq ‘sportimages.zip’ -d ‘.’

# %% [markdown]
# Instalar otras librerías Python con Pip

# %%
pip install gensim

# %% [markdown]
# Upload local files

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-36659b4a-358f-4151-ab00-2218de3762b8" name="files[]" multiple disabled />
#      <output id="result-36659b4a-358f-4151-ab00-2218de3762b8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving letra.txt to letra.txt

# %% [markdown]
# Run an existing .py script

# %%
# !python3 /content/drive/Project/script.py
